# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

from agents.graphs.orchestrator import agents_orchestrator
from agents.graphs.builder import AgentGraphRegistry


display(
    Image(
        agents_orchestrator.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API
        )
    )
)

# %%
display(
    Image(
        AgentGraphRegistry.TECHNICAL_MODE.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API
        )
    )
)
